# %% [markdown]
# # Assumptions
#
# Hoping you are familiar with basic python syntax and Lambda functions
# <br />Lambda function Blog : https://www.programiz.com/python-programming/anonymous-function <br /><br />
# Also you can find some Blogs that might help you better understand the concept for groupby:
# <br />Link : https://towardsdatascience.com/how-to-use-the-split-apply-combine-strategy-in-pandas-groupby-29e0eb44b62e

# %% [markdown]
# # Why/When Groupby?
#   During your EDA/Data analysis/feature engineering there will always come a point where you would want to split the data based on certain groups/categories, and get relevant statistical inferences from it.
#
# Let's see some scenerios below. let's start by making a dummy Data

# %%
import numpy as np
import pandas as pd

# %%
"""
  Lets start with a assumption that there is a class of 300 students and they have given there one fav subject a rating in range of 1-10 from 6 unique subject .
"""
n_studs = 300
HouseOne = pd.DataFrame({
    "Name":["Name_"+str(i) for i in range(n_studs)],
    "Subject":np.random.choice(["Subject_"+str(i) for i in range(6)], size=n_studs),
    "Rating":np.random.uniform(low=1, high=10, size=n_studs)
})

# %%
HouseOne.sample(10) # will give you 10 random points in any order
# Out:
#          Name    Subject    Rating
# 114  Name_114  Subject_3  8.898470
# 9      Name_9  Subject_2  6.895104
# 73    Name_73  Subject_3  9.027637
# 13    Name_13  Subject_1  3.088946
# 288  Name_288  Subject_3  6.869682
# 167  Name_167  Subject_4  4.603252
# 117  Name_117  Subject_0  3.516517
# 24    Name_24  Subject_3  7.025708
# 44    Name_44  Subject_4  7.427637
# 66    Name_66  Subject_5  6.116709

# %% [markdown]
# Ok, now we have a sample data, let's see how much average rating each subject has

# %%
"""
Hold on here a second, notice groupby("Subject") will filter you data into groups of each individual unique subject and return a groupby OBJECT.!, 
if you iterate over these objects you get a tuple of group name(here, subname & the filtered data)
"""
for name, group in HouseOne.groupby("Subject"):
  print(name)
  print(group)
  print(f"Group Name is {name}")
# Out:
# Subject_0
#          Name    Subject    Rating
# 4      Name_4  Subject_0  7.664599
# 8      Name_8  Subject_0  3.747902
# 17    Name_17  Subject_0  2.943420
# 20    Name_20  Subject_0  4.707439
# 26    Name_26  Subject_0  7.008340
# 27    Name_27  Subject_0  5.251544
# 47    Name_47  Subject_0  7.521537
# 50    Name_50  Subject_0  7.701747
# 54    Name_54  Subject_0  4.909955
# 58    Name_58  Subject_0  3.765084
# 63    Name_63  Subject_0  5.970750
# 68    Name_68  Subject_0  6.212082
# 70    Name_70  Subject_0  9.578245
# 72    Name_72  Subject_0  2.755612
# 74    Name_74  Subject_0  6.980206
# 92    Name_92  Subject_0  6.568149
# 101  Name_101  Subject_0  6.949784
# 107  Name_107  Subject_0  9.801355
# 116  Name_116  Subject_0  8.503369
# 117  Name_117  Subject_0  3.516517
# 121  Name_121  Subject_0  7.446221
# 122  Name_122  Subject_0  2.991187
# 124  Name_124  Subject_0  9.308572
# 129  Name_129  Subject_0  9.999444
# 142  Name_142  Subject_0  3.328223
# 152  Name_152  Subject_0  7.580553
# 155  Name_155  Subject_0  3.899070
# 157  Name_157  Subject_0  3.487355
# 162  Name_162  Subject_0  7.964682
# 163  Name_163  Subject_0  9.062957
# 175  Name_175  Subject_0  8.434183
# 190  Name_190  Subject_0  9.502448
# 194  Name_194  Subject_0  9.261167
# 198  Name_198  Subject_0  2.677539
# 201  Name_201  Subject_0  6.462207
# 203  Name_203  Subject_0  3.479305
# 216  Name_216  Subject_0  9.669375
# 219  Name_219  Subject_0  4.392225
# 228  Name_228  Subject_0  5.083688
# 229  Name_229  Subject_0  7.958296
# 230  Name_230  Subject_0  1.156994
# 239  Name_239  Subject_0  9.138748
# 245  Name_245  Subject_0  3.369897
# 254  Name_254  Subject_0  4.130651
# 257  Name_257  Subject_0  9.492030
# 264  Name_264  Subject_0  9.900154
# 280  Name_280  Subject_0  4.893814
# 286  Name_286  Subject_0  1.687835
# 290  Name_290  Subject_0  4.915902
# 291  Name_291  Subject_0  7.819121
# 295  Name_295  Subject_0  6.725507
# Group Name is Subject_0
# Subject_1
#          Name    Subject    Rating
# 0      Name_0  Subject_1  2.106866
# 3      Name_3  Subject_1  1.633120
# 13    Name_13  Subject_1  3.088946
# 28    Name_28  Subject_1  7.573859
# 33    Name_33  Subject_1  3.368651
# 36    Name_36  Subject_1  3.750269
# 42    Name_42  Subject_1  2.203676
# 43    Name_43  Subject_1  6.440164
# 46    Name_46  Subject_1  7.744461
# 61    Name_61  Subject_1  3.083753
# 64    Name_64  Subject_1  4.424974
# 67    Name_67  Subject_1  3.584229
# 80    Name_80  Subject_1  3.606141
# 86    Name_86  Subject_1  5.312319
# 97    Name_97  Subject_1  9.047779
# 104  Name_104  Subject_1  8.351898
# 110  Name_110  Subject_1  7.080623
# 120  Name_120  Subject_1  2.134556
# 123  Name_123  Subject_1  2.839995
# 125  Name_125  Subject_1  7.325129
# 126  Name_126  Subject_1  7.466574
# 136  Name_136  Subject_1  9.480833
# 137  Name_137  Subject_1  2.003286
# 141  Name_141  Subject_1  4.318043
# 145  Name_145  Subject_1  9.265543
# 149  Name_149  Subject_1  8.794317
# 168  Name_168  Subject_1  6.156902
# 179  Name_179  Subject_1  9.560861
# 187  Name_187  Subject_1  5.081949
# 188  Name_188  Subject_1  9.730552
# 199  Name_199  Subject_1  4.326941
# 204  Name_204  Subject_1  9.684602
# 206  Name_206  Subject_1  9.368470
# 208  Name_208  Subject_1  2.737806
# 213  Name_213  Subject_1  7.298804
# 215  Name_215  Subject_1  7.755030
# 224  Name_224  Subject_1  5.739718
# 225  Name_225  Subject_1  2.189404
# 227  Name_227  Subject_1  6.458658
# 233  Name_233  Subject_1  7.307079
# 234  Name_234  Subject_1  7.681639
# 242  Name_242  Subject_1  1.726447
# 250  Name_250  Subject_1  9.740035
# 253  Name_253  Subject_1  9.890786
# 255  Name_255  Subject_1  6.898740
# 261  Name_261  Subject_1  2.824717
# 268  Name_268  Subject_1  2.541818
# 272  Name_272  Subject_1  6.729728
# 276  Name_276  Subject_1  5.448141
# 282  Name_282  Subject_1  5.895073
# 287  Name_287  Subject_1  1.208289
# 298  Name_298  Subject_1  1.976273
# Group Name is Subject_1
# Subject_2
#          Name    Subject    Rating
# 5      Name_5  Subject_2  3.121444
# 6      Name_6  Subject_2  1.928478
# 9      Name_9  Subject_2  6.895104
# 12    Name_12  Subject_2  9.126248
# 23    Name_23  Subject_2  3.307681
# 25    Name_25  Subject_2  8.947460
# 31    Name_31  Subject_2  1.718055
# 38    Name_38  Subject_2  6.217929
# 45    Name_45  Subject_2  8.553726
# 48    Name_48  Subject_2  2.038327
# 81    Name_81  Subject_2  7.374736
# 83    Name_83  Subject_2  2.824149
# 89    Name_89  Subject_2  5.909299
# 90    Name_90  Subject_2  7.200161
# 91    Name_91  Subject_2  3.880210
# 94    Name_94  Subject_2  9.469249
# 105  Name_105  Subject_2  8.926833
# 112  Name_112  Subject_2  5.776602
# 118  Name_118  Subject_2  5.121305
# 130  Name_130  Subject_2  6.394057
# 131  Name_131  Subject_2  9.736758
# 143  Name_143  Subject_2  9.212162
# 154  Name_154  Subject_2  1.868901
# 156  Name_156  Subject_2  3.627359
# 158  Name_158  Subject_2  3.557852
# 172  Name_172  Subject_2  9.471899
# 174  Name_174  Subject_2  9.777260
# 176  Name_176  Subject_2  4.545981
# 181  Name_181  Subject_2  5.685367
# 189  Name_189  Subject_2  6.276706
# 191  Name_191  Subject_2  8.122015
# 195  Name_195  Subject_2  3.957759
# 196  Name_196  Subject_2  8.198389
# 197  Name_197  Subject_2  7.837483
# 205  Name_205  Subject_2  1.505095
# 209  Name_209  Subject_2  5.849254
# 210  Name_210  Subject_2  7.410936
# 211  Name_211  Subject_2  8.811792
# 214  Name_214  Subject_2  1.213181
# 231  Name_231  Subject_2  7.531170
# 237  Name_237  Subject_2  6.461980
# 241  Name_241  Subject_2  4.609770
# 246  Name_246  Subject_2  5.945205
# 275  Name_275  Subject_2  3.590839
# 277  Name_277  Subject_2  4.250740
# 278  Name_278  Subject_2  6.948050
# 279  Name_279  Subject_2  7.249247
# 285  Name_285  Subject_2  3.503987
# 297  Name_297  Subject_2  9.824164
# Group Name is Subject_2
# Subject_3
#          Name    Subject    Rating
# 15    Name_15  Subject_3  9.810748
# 19    Name_19  Subject_3  3.050143
# 24    Name_24  Subject_3  7.025708
# 29    Name_29  Subject_3  3.654001
# 30    Name_30  Subject_3  4.559830
# 34    Name_34  Subject_3  4.711554
# 35    Name_35  Subject_3  1.891715
# 39    Name_39  Subject_3  6.007382
# 41    Name_41  Subject_3  9.684943
# 51    Name_51  Subject_3  4.287186
# 52    Name_52  Subject_3  3.297941
# 73    Name_73  Subject_3  9.027637
# 75    Name_75  Subject_3  7.950032
# 77    Name_77  Subject_3  8.762772
# 85    Name_85  Subject_3  2.437113
# 95    Name_95  Subject_3  2.808906
# 99    Name_99  Subject_3  2.452615
# 102  Name_102  Subject_3  8.991730
# 113  Name_113  Subject_3  2.940078
# 114  Name_114  Subject_3  8.898470
# 127  Name_127  Subject_3  6.859757
# 138  Name_138  Subject_3  9.791243
# 147  Name_147  Subject_3  7.498774
# 164  Name_164  Subject_3  5.476105
# 165  Name_165  Subject_3  3.345961
# 170  Name_170  Subject_3  8.260940
# 178  Name_178  Subject_3  9.423926
# 180  Name_180  Subject_3  7.863098
# 183  Name_183  Subject_3  1.023230
# 185  Name_185  Subject_3  4.726962
# 186  Name_186  Subject_3  3.391623
# 200  Name_200  Subject_3  4.339955
# 207  Name_207  Subject_3  6.837184
# 220  Name_220  Subject_3  7.975241
# 221  Name_221  Subject_3  2.693658
# 222  Name_222  Subject_3  5.691727
# 244  Name_244  Subject_3  2.912976
# 249  Name_249  Subject_3  3.547458
# 251  Name_251  Subject_3  4.273799
# 256  Name_256  Subject_3  4.197012
# 260  Name_260  Subject_3  4.549925
# 263  Name_263  Subject_3  7.240571
# 265  Name_265  Subject_3  2.758109
# 269  Name_269  Subject_3  5.014825
# 270  Name_270  Subject_3  3.675474
# 271  Name_271  Subject_3  1.778262
# 283  Name_283  Subject_3  7.611569
# 288  Name_288  Subject_3  6.869682
# 292  Name_292  Subject_3  3.930997
# 294  Name_294  Subject_3  2.862236
# 296  Name_296  Subject_3  9.627529
# 299  Name_299  Subject_3  9.246434
# Group Name is Subject_3
# Subject_4
#          Name    Subject    Rating
# 7      Name_7  Subject_4  1.248006
# 10    Name_10  Subject_4  8.954331
# 11    Name_11  Subject_4  3.964623
# 14    Name_14  Subject_4  8.951457
# 21    Name_21  Subject_4  9.574121
# 37    Name_37  Subject_4  6.358927
# 44    Name_44  Subject_4  7.427637
# 55    Name_55  Subject_4  6.974026
# 57    Name_57  Subject_4  2.949894
# 59    Name_59  Subject_4  5.039113
# 60    Name_60  Subject_4  5.309010
# 62    Name_62  Subject_4  5.321391
# 65    Name_65  Subject_4  3.776771
# 69    Name_69  Subject_4  4.707619
# 71    Name_71  Subject_4  9.160264
# 76    Name_76  Subject_4  2.531537
# 79    Name_79  Subject_4  1.856215
# 87    Name_87  Subject_4  2.122991
# 93    Name_93  Subject_4  7.280980
# 96    Name_96  Subject_4  4.399700
# 98    Name_98  Subject_4  8.013977
# 100  Name_100  Subject_4  7.831890
# 106  Name_106  Subject_4  9.145169
# 108  Name_108  Subject_4  7.966948
# 111  Name_111  Subject_4  9.794213
# 128  Name_128  Subject_4  9.584616
# 133  Name_133  Subject_4  9.478201
# 134  Name_134  Subject_4  8.934521
# 135  Name_135  Subject_4  3.744782
# 140  Name_140  Subject_4  3.926704
# 148  Name_148  Subject_4  9.980813
# 153  Name_153  Subject_4  4.147344
# 161  Name_161  Subject_4  3.797502
# 166  Name_166  Subject_4  1.474007
# 167  Name_167  Subject_4  4.603252
# 169  Name_169  Subject_4  2.921043
# 177  Name_177  Subject_4  2.476978
# 192  Name_192  Subject_4  3.945378
# 202  Name_202  Subject_4  4.622091
# 212  Name_212  Subject_4  5.560544
# 217  Name_217  Subject_4  8.611974
# 226  Name_226  Subject_4  7.250816
# 232  Name_232  Subject_4  7.724760
# 235  Name_235  Subject_4  3.626263
# 238  Name_238  Subject_4  5.842593
# 240  Name_240  Subject_4  4.212398
# 243  Name_243  Subject_4  9.153692
# 247  Name_247  Subject_4  4.709078
# 248  Name_248  Subject_4  9.158076
# 258  Name_258  Subject_4  5.700782
# 259  Name_259  Subject_4  1.808280
# 266  Name_266  Subject_4  9.642087
# 267  Name_267  Subject_4  4.321633
# 273  Name_273  Subject_4  4.062334
# 274  Name_274  Subject_4  6.567919
# 289  Name_289  Subject_4  1.455263
# Group Name is Subject_4
# Subject_5
#          Name    Subject    Rating
# 1      Name_1  Subject_5  7.764332
# 2      Name_2  Subject_5  1.016517
# 16    Name_16  Subject_5  5.368877
# 18    Name_18  Subject_5  8.659473
# 22    Name_22  Subject_5  2.513093
# 32    Name_32  Subject_5  1.025798
# 40    Name_40  Subject_5  4.697461
# 49    Name_49  Subject_5  2.382767
# 53    Name_53  Subject_5  4.978439
# 56    Name_56  Subject_5  3.079344
# 66    Name_66  Subject_5  6.116709
# 78    Name_78  Subject_5  2.776466
# 82    Name_82  Subject_5  2.166898
# 84    Name_84  Subject_5  7.519082
# 88    Name_88  Subject_5  8.682999
# 103  Name_103  Subject_5  4.819126
# 109  Name_109  Subject_5  3.251455
# 115  Name_115  Subject_5  3.733701
# 119  Name_119  Subject_5  2.344697
# 132  Name_132  Subject_5  9.861275
# 139  Name_139  Subject_5  6.800770
# 144  Name_144  Subject_5  8.395964
# 146  Name_146  Subject_5  8.662750
# 150  Name_150  Subject_5  6.953822
# 151  Name_151  Subject_5  8.386743
# 159  Name_159  Subject_5  5.514148
# 160  Name_160  Subject_5  5.821020
# 171  Name_171  Subject_5  7.653976
# 173  Name_173  Subject_5  3.955190
# 182  Name_182  Subject_5  9.189052
# 184  Name_184  Subject_5  3.936514
# 193  Name_193  Subject_5  4.783645
# 218  Name_218  Subject_5  4.177117
# 223  Name_223  Subject_5  9.449660
# 236  Name_236  Subject_5  8.898932
# 252  Name_252  Subject_5  8.167427
# 262  Name_262  Subject_5  7.563720
# 281  Name_281  Subject_5  3.060747
# 284  Name_284  Subject_5  2.674977
# 293  Name_293  Subject_5  4.868113
# Group Name is Subject_5

# %%
# %%time
for name, group in HouseOne.groupby("Subject"):
  print(f"Subject Name is {name} and Subject Avg. rating is {group['Rating'].mean()}") # now we know groups represent the  subjects
# Out:
# Subject Name is Subject_0 and Subject Avg. rating is 6.221117399677172
# Subject Name is Subject_1 and Subject Avg. rating is 5.615162821682815
# Subject Name is Subject_2 and Subject Avg. rating is 5.945150061262556
# Subject Name is Subject_3 and Subject Avg. rating is 5.529745150060131
# Subject Name is Subject_4 and Subject Avg. rating is 5.780473839570078
# Subject Name is Subject_5 and Subject Avg. rating is 5.541819975490779
# CPU times: user 7.19 ms, sys: 960 µs, total: 8.15 ms
# Wall time: 7.32 ms

# %%
for name, group in HouseOne.groupby("Subject"):
  print(f"Now Printing Filtered Data of only : {name}")
  print("*"*50)
  print(group.head(3))
  print("*"*50)
# Out:
# Now Printing Filtered Data of only : Subject_0
# **************************************************
#        Name    Subject    Rating
# 4    Name_4  Subject_0  7.664599
# 8    Name_8  Subject_0  3.747902
# 17  Name_17  Subject_0  2.943420
# **************************************************
# Now Printing Filtered Data of only : Subject_1
# **************************************************
#        Name    Subject    Rating
# 0    Name_0  Subject_1  2.106866
# 3    Name_3  Subject_1  1.633120
# 13  Name_13  Subject_1  3.088946
# **************************************************
# Now Printing Filtered Data of only : Subject_2
# **************************************************
#      Name    Subject    Rating
# 5  Name_5  Subject_2  3.121444
# 6  Name_6  Subject_2  1.928478
# 9  Name_9  Subject_2  6.895104
# **************************************************
# Now Printing Filtered Data of only : Subject_3
# **************************************************
#        Name    Subject    Rating
# 15  Name_15  Subject_3  9.810748
# 19  Name_19  Subject_3  3.050143
# 24  Name_24  Subject_3  7.025708
# **************************************************
# Now Printing Filtered Data of only : Subject_4
# **************************************************
#        Name    Subject    Rating
# 7    Name_7  Subject_4  1.248006
# 10  Name_10  Subject_4  8.954331
# 11  Name_11  Subject_4  3.964623
# **************************************************
# Now Printing Filtered Data of only : Subject_5
# **************************************************
#        Name    Subject    Rating
# 1    Name_1  Subject_5  7.764332
# 2    Name_2  Subject_5  1.016517
# 16  Name_16  Subject_5  5.368877
# **************************************************

# %% [markdown]
# I hope you abstractly get the point here., but looping over all values for mean or any statistical value of individual groups isn't really pythonic so let's try another way

# %%
HouseOne.groupby("Subject") #returns the groupby object

# %%
# %%time
HouseOne.groupby("Subject")['Rating'].mean() # what just happened?, so basically first groups of each subjects were created withing these group rating column was extracted & mean of that value was taken. simple.
# Out:
# CPU times: user 2.67 ms, sys: 0 ns, total: 2.67 ms
# Wall time: 10.8 ms
# Subject
# Subject_0    6.221117
# Subject_1    5.615163
# Subject_2    5.945150
# Subject_3    5.529745
# Subject_4    5.780474
# Subject_5    5.541820
# Name: Rating, dtype: float64

# %% [markdown]
# Check the time diffrence & match the values where we looped over group and now where we used short cute method, if the data is big enough this time difference would be significant., try it once by increasing n_rows from 300 to 3,000,000

# %% [markdown]
# #### Aggregate functions
# How to get Multiple, Satistical infrences from groups at once?
#   Let's try to get mean, median, mode, count values of rating from each group

# %%
"""
  There is one rule for Aggregate functions ----::---- Always remember the aggregate function assumes that function that you want to use will return a single value.
  for e.g : 
    for a column -> mean would return a single value which is the average of that column.
    but cant use a function like value_counts, which return multiple values. but i can filter the most/least frequent element from it to return as value see getmeMode function
  You can even pass your custom/user defined function, i am here going to pass a user defined function that returns mode of the series/column

"""
def getMeMode(x):
  return x.value_counts().index[0] # return value of most frequent element. Note: x is the entire column of rating of any particular group, and i am returning a *single* value which mode from my defined function.
  
stats = HouseOne.groupby("Subject")["Rating"].agg({"mean", "median", "count", np.sum, getMeMode}) # instead of np.sum you can also use "sum", getMeMode signifies as the address/refrence of function
stats # columns are returned in random order you can get a proper order by filtering columns in partcular order [ColA, ColB, ..., ColN]
# Out:
#              median      mean  getMeMode  count         sum
# Subject
# Subject_0  6.568149  6.221117   7.580553     51  317.276987
# Subject_1  5.817395  5.615163   4.424974     52  291.988467
# Subject_2  6.217929  5.945150   5.121305     49  291.312353
# Subject_3  4.719258  5.529745   4.726962     52  287.546748
# Subject_4  5.315201  5.780474   1.856215     56  323.706535
# Subject_5  5.173658  5.541820   8.682999     40  221.672799

# %% [markdown]
# #### Apply/ApplyMap/Map
#
# There could be scenerios where you might want to apply some logic/function on dataframe or series itself.

# %%
"""
  Apply/ApplyMap/Map are functions that help you intract with groups you created & even manipulate values for same.
  Map - Applied only to a series(columns), and is element wise
  ApplyMap - Applied to only DataFrame, and is element wise
  Apply - Can be used on both.
  .
  .
  Let's create a new column in Dataframe and convert the rating to some string value.
"""
rating_to_grade = {
    10 : "O",
     9 : "E",
     8 : "A",
     7 : "B",
     6 : "C",
     5 : "D",
     4 : "E",
     3 : "F",
     2 : "Nailed it.!",
     1 : "Legendary"
}

# converting Rating which is continous to discrete values
HouseOne['discrete_rating'] = HouseOne['Rating'].apply(np.ceil) # you can also try map here since we are just manipulating a Series here i.e. Rating
HouseOne.head()
# Out:
#      Name    Subject    Rating  discrete_rating
# 0  Name_0  Subject_1  2.106866              3.0
# 1  Name_1  Subject_5  7.764332              8.0
# 2  Name_2  Subject_5  1.016517              2.0
# 3  Name_3  Subject_1  1.633120              2.0
# 4  Name_4  Subject_0  7.664599              8.0

# %%
HouseOne['Grade'] = HouseOne['discrete_rating'].map(rating_to_grade)
HouseOne.sample(10)
# Out:
#          Name    Subject    Rating  discrete_rating Grade
# 140  Name_140  Subject_4  3.926704              4.0     E
# 293  Name_293  Subject_5  4.868113              5.0     D
# 296  Name_296  Subject_3  9.627529             10.0     O
# 295  Name_295  Subject_0  6.725507              7.0     B
# 243  Name_243  Subject_4  9.153692             10.0     O
# 217  Name_217  Subject_4  8.611974              9.0     E
# 253  Name_253  Subject_1  9.890786             10.0     O
# 143  Name_143  Subject_2  9.212162             10.0     O
# 231  Name_231  Subject_2  7.531170              8.0     A
# 66    Name_66  Subject_5  6.116709              7.0     B

# %%
"""
  Let's say you want to do some manipulation on each row and value of dataframe, idk maybe add H1 for House_one to every value let's try to do that
"""
HouseOne.applymap(lambda x : str(x)+ "_H1") # as you can see applymap added _H1 to each element of data.
# Out:
#             Name       Subject  ... discrete_rating           Grade
# 0      Name_0_H1  Subject_1_H1  ...          3.0_H1            F_H1
# 1      Name_1_H1  Subject_5_H1  ...          8.0_H1            A_H1
# 2      Name_2_H1  Subject_5_H1  ...          2.0_H1  Nailed it.!_H1
# 3      Name_3_H1  Subject_1_H1  ...          2.0_H1  Nailed it.!_H1
# 4      Name_4_H1  Subject_0_H1  ...          8.0_H1            A_H1
# ..           ...           ...  ...             ...             ...
# 295  Name_295_H1  Subject_0_H1  ...          7.0_H1            B_H1
# 296  Name_296_H1  Subject_3_H1  ...         10.0_H1            O_H1
# 297  Name_297_H1  Subject_2_H1  ...         10.0_H1            O_H1
# 298  Name_298_H1  Subject_1_H1  ...          2.0_H1  Nailed it.!_H1
# 299  Name_299_H1  Subject_3_H1  ...         10.0_H1            O_H1
#
# [300 rows x 5 columns]

# %% [markdown]
# ##### Ley's say you want to Do some manipulation on groups of data or run your function for each group

# %%
def myFunction(groupName, groupData):
  """
    @ groupName param : it is the current groupName which is being used 
    @ x : x is the row of each group
  """
  print(f"Currently this group Name is {groupName}")
  print(f"Curious what X contains? :\n {groupData.head(2)}") # x is simply the data that you extracted. You can assume that groupData is the a dataframe & apply your logic to it based on your intrest.



HouseOne.groupby("Subject").apply(lambda x: myFunction(x.name, x)) # x.name is passed just for illustration purpose i hardly imagine u'll need that., btw if u r trying just try to use map instead of apply n see what happens
# Out:
# Currently this group Name is Subject_0
# Curious what X contains? :
#       Name    Subject    Rating  discrete_rating Grade
# 4  Name_4  Subject_0  7.664599              8.0     A
# 8  Name_8  Subject_0  3.747902              4.0     E
# Currently this group Name is Subject_1
# Curious what X contains? :
#       Name    Subject    Rating  discrete_rating        Grade
# 0  Name_0  Subject_1  2.106866              3.0            F
# 3  Name_3  Subject_1  1.633120              2.0  Nailed it.!
# Currently this group Name is Subject_2
# Curious what X contains? :
#       Name    Subject    Rating  discrete_rating        Grade
# 5  Name_5  Subject_2  3.121444              4.0            E
# 6  Name_6  Subject_2  1.928478              2.0  Nailed it.!
# Currently this group Name is Subject_3
# Curious what X contains? :
#         Name    Subject    Rating  discrete_rating Grade
# 15  Name_15  Subject_3  9.810748             10.0     O
# 19  Name_19  Subject_3  3.050143              4.0     E
# Currently this group Name is Subject_4
# Curious what X contains? :
#         Name    Subject    Rating  discrete_rating        Grade
# 7    Name_7  Subject_4  1.248006              2.0  Nailed it.!
# 10  Name_10  Subject_4  8.954331              9.0            E
# Currently this group Name is Subject_5
# Curious what X contains? :
#       Name    Subject    Rating  discrete_rating        Grade
# 1  Name_1  Subject_5  7.764332              8.0            A
# 2  Name_2  Subject_5  1.016517              2.0  Nailed it.!
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# Let's see what subject got what frequent grade

# %%
HouseOne.groupby("Subject").apply(lambda x: x['Grade'].value_counts().index[0]) # if you are confused what happened here, try to decode it line by line n u'll get the point.
# Out:
# Subject
# Subject_0    O
# Subject_1    O
# Subject_2    E
# Subject_3    E
# Subject_4    E
# Subject_5    E
# dtype: object

# %% [markdown]
# ## Aggregating Multiple Columns

# %%
# here we aggregates individual columns by specifying the dictionary what operation we want also we can pass custom functons here i passed getMeMoode created earlier
HouseOne.groupby("Subject").agg({"Rating":"mean", "discrete_rating":"median", "Grade":getMeMode})
# Out:
#              Rating  discrete_rating Grade
# Subject
# Subject_0  6.221117              7.0     O
# Subject_1  5.615163              6.0     O
# Subject_2  5.945150              7.0     E
# Subject_3  5.529745              5.0     E
# Subject_4  5.780474              6.0     E
# Subject_5  5.541820              5.5     E

# %%
my_list = [1, 5, 4, 6, 8, 11, 3, 12]

new_list = list(filter(lambda x: (x%2 == 0) , my_list))

print(new_list)
# Out:
# [4, 6, 8, 12]

# %%
list(filter(lambda x: (x%2 == 0) , my_list))
# Out:
# [4, 6, 8, 12]

# %%
def myFunction(groupData):
  """
    @ groupName param : it is the current groupName which is being used 
    @ x : x is the row of each group
  """

  print(f"Curious what X contains? :\n {groupData}") # x is simply the data that you extracted. You can assume that groupData is the a dataframe & apply your logic to it based on your intrest.

for name,group in HouseOne.groupby("Subject"):
  group.applymap(lambda x: myFunction(x))
#HouseOne.groupby("Subject").applymap(lambda x: myFunction(x)) # x.name is passed just for illustration purpose i hardly imagine u'll need that., btw if u r trying just try to use map instead of apply n see what happens
# Out:
# Curious what X contains? :
#  Name_4
# Curious what X contains? :
#  Name_8
# Curious what X contains? :
#  Name_17
# Curious what X contains? :
#  Name_20
# Curious what X contains? :
#  Name_26
# Curious what X contains? :
#  Name_27
# Curious what X contains? :
#  Name_47
# Curious what X contains? :
#  Name_50
# Curious what X contains? :
#  Name_54
# Curious what X contains? :
#  Name_58
# Curious what X contains? :
#  Name_63
# Curious what X contains? :
#  Name_68
# Curious what X contains? :
#  Name_70
# Curious what X contains? :
#  Name_72
# Curious what X contains? :
#  Name_74
# Curious what X contains? :
#  Name_92
# Curious what X contains? :
#  Name_101
# Curious what X contains? :
#  Name_107
# Curious what X contains? :
#  Name_116
# Curious what X contains? :
#  Name_117
# Curious what X contains? :
#  Name_121
# Curious what X contains? :
#  Name_122
# Curious what X contains? :
#  Name_124
# Curious what X contains? :
#  Name_129
# Curious what X contains? :
#  Name_142
# Curious what X contains? :
#  Name_152
# Curious what X contains? :
#  Name_155
# Curious what X contains? :
#  Name_157
# Curious what X contains? :
#  Name_162
# Curious what X contains? :
#  Name_163
# Curious what X contains? :
#  Name_175
# Curious what X contains? :
#  Name_190
# Curious what X contains? :
#  Name_194
# Curious what X contains? :
#  Name_198
# Curious what X contains? :
#  Name_201
# Curious what X contains? :
#  Name_203
# Curious what X contains? :
#  Name_216
# Curious what X contains? :
#  Name_219
# Curious what X contains? :
#  Name_228
# Curious what X contains? :
#  Name_229
# Curious what X contains? :
#  Name_230
# Curious what X contains? :
#  Name_239
# Curious what X contains? :
#  Name_245
# Curious what X contains? :
#  Name_254
# Curious what X contains? :
#  Name_257
# Curious what X contains? :
#  Name_264
# Curious what X contains? :
#  Name_280
# Curious what X contains? :
#  Name_286
# Curious what X contains? :
#  Name_290
# Curious what X contains? :
#  Name_291
# Curious what X contains? :
#  Name_295
# Curious what X contains? :
#  Subject_0
# Curious what X contains? :
#  Subject_0
# Curious what X contains? :
#  Subject_0
# Curious what X contains? :
#  Subject_0
# Curious what X contains? :
#  Subject_0
# Curious what X contains? :
#  Subject_0
# Curious what X contains? :
#  Subject_0
# Curious what X contains? :
#  Subject_0
# Curious what X contains? :
#  Subject_0
# Curious what X contains? :
#  Subject_0
# Curious what X contains? :
#  Subject_0
# Curious what X contains? :
#  Subject_0
# Curious what X contains? :
#  Subject_0
# Curious what X contains? :
#  Subject_0
# Curious what X contains? :
#  Subject_0
# Curious what X contains? :
#  Subject_0
# Curious what X contains? :
#  Subject_0
# Curious what X contains? :
#  Subject_0
# Curious what X contains? :
#  Subject_0
# Curious what X contains? :
#  Subject_0
# Curious what X contains? :
#  Subject_0
# Curious what X contains? :
#  Subject_0
# Curious what X contains? :
#  Subject_0
# Curious what X contains? :
#  Subject_0
# Curious what X contains? :
#  Subject_0
# Curious what X contains? :
#  Subject_0
# Curious what X contains? :
#  Subject_0
# Curious what X contains? :
#  Subject_0
# Curious what X contains? :
#  Subject_0
# Curious what X contains? :
#  Subject_0
# Curious what X contains? :
#  Subject_0
# Curious what X contains? :
#  Subject_0
# Curious what X contains? :
#  Subject_0
# Curious what X contains? :
#  Subject_0
# Curious what X contains? :
#  Subject_0
# Curious what X contains? :
#  Subject_0
# Curious what X contains? :
#  Subject_0
# Curious what X contains? :
#  Subject_0
# Curious what X contains? :
#  Subject_0
# Curious what X contains? :
#  Subject_0
# Curious what X contains? :
#  Subject_0
# Curious what X contains? :
#  Subject_0
# Curious what X contains? :
#  Subject_0
# Curious what X contains? :
#  Subject_0
# Curious what X contains? :
#  Subject_0
# Curious what X contains? :
#  Subject_0
# Curious what X contains? :
#  Subject_0
# Curious what X contains? :
#  Subject_0
# Curious what X contains? :
#  Subject_0
# Curious what X contains? :
#  Subject_0
# Curious what X contains? :
#  Subject_0
# Curious what X contains? :
#  7.6645992588906715
# Curious what X contains? :
#  3.7479016426404312
# Curious what X contains? :
#  2.943419866388799
# Curious what X contains? :
#  4.707438995366564
# Curious what X contains? :
#  7.008340324735785
# Curious what X contains? :
#  5.251544144828232
# Curious what X contains? :
#  7.521537075769381
# Curious what X contains? :
#  7.701746838660788
# Curious what X contains? :
#  4.9099550041313575
# Curious what X contains? :
#  3.7650843853986196
# Curious what X contains? :
#  5.970750139938793
# Curious what X contains? :
#  6.212082470077106
# Curious what X contains? :
#  9.578245255254641
# Curious what X contains? :
#  2.7556116966642117
# Curious what X contains? :
#  6.980205810547551
# Curious what X contains? :
#  6.568149369953155
# Curious what X contains? :
#  6.949783883452654
# Curious what X contains? :
#  9.801355442883821
# Curious what X contains? :
#  8.503368781630423
# Curious what X contains? :
#  3.5165174285209746
# Curious what X contains? :
#  7.446220817495082
# Curious what X contains? :
#  2.991187410467076
# Curious what X contains? :
#  9.308571900391737
# Curious what X contains? :
#  9.999444421404093
# Curious what X contains? :
#  3.3282229309126614
# Curious what X contains? :
#  7.580552538699843
# Curious what X contains? :
#  3.8990703922505014
# Curious what X contains? :
#  3.48735495521559
# Curious what X contains? :
#  7.96468202130389
# Curious what X contains? :
#  9.062956715221237
# Curious what X contains? :
#  8.43418339221196
# Curious what X contains? :
#  9.50244831592919
# Curious what X contains? :
#  9.261166684513567
# Curious what X contains? :
#  2.6775390163860946
# Curious what X contains? :
#  6.4622071850550125
# Curious what X contains? :
#  3.4793052781641434
# Curious what X contains? :
#  9.66937506714469
# Curious what X contains? :
#  4.392224849197008
# Curious what X contains? :
#  5.0836884759085015
# Curious what X contains? :
#  7.958295918039813
# Curious what X contains? :
#  1.1569938533359108
# Curious what X contains? :
#  9.13874829671065
# Curious what X contains? :
#  3.3698966421970034
# Curious what X contains? :
#  4.130650825402848
# Curious what X contains? :
#  9.492029648862198
# Curious what X contains? :
#  9.900153986535583
# Curious what X contains? :
#  4.893813861316552
# Curious what X contains? :
#  1.687835210806301
# Curious what X contains? :
#  4.915901610439143
# Curious what X contains? :
#  7.819120762922426
# Curious what X contains? :
#  6.725506583361409
# Curious what X contains? :
#  8.0
# Curious what X contains? :
#  4.0
# Curious what X contains? :
#  3.0
# Curious what X contains? :
#  5.0
# Curious what X contains? :
#  8.0
# Curious what X contains? :
#  6.0
# Curious what X contains? :
#  8.0
# Curious what X contains? :
#  8.0
# Curious what X contains? :
#  5.0
# Curious what X contains? :
#  4.0
# Curious what X contains? :
#  6.0
# Curious what X contains? :
#  7.0
# Curious what X contains? :
#  10.0
# Curious what X contains? :
#  3.0
# Curious what X contains? :
#  7.0
# Curious what X contains? :
#  7.0
# Curious what X contains? :
#  7.0
# Curious what X contains? :
#  10.0
# Curious what X contains? :
#  9.0
# Curious what X contains? :
#  4.0
# Curious what X contains? :
#  8.0
# Curious what X contains? :
#  3.0
# Curious what X contains? :
#  10.0
# Curious what X contains? :
#  10.0
# Curious what X contains? :
#  4.0
# Curious what X contains? :
#  8.0
# Curious what X contains? :
#  4.0
# Curious what X contains? :
#  4.0
# Curious what X contains? :
#  8.0
# Curious what X contains? :
#  10.0
# Curious what X contains? :
#  9.0
# Curious what X contains? :
#  10.0
# Curious what X contains? :
#  10.0
# Curious what X contains? :
#  3.0
# Curious what X contains? :
#  7.0
# Curious what X contains? :
#  4.0
# Curious what X contains? :
#  10.0
# Curious what X contains? :
#  5.0
# Curious what X contains? :
#  6.0
# Curious what X contains? :
#  8.0
# Curious what X contains? :
#  2.0
# Curious what X contains? :
#  10.0
# Curious what X contains? :
#  4.0
# Curious what X contains? :
#  5.0
# Curious what X contains? :
#  10.0
# Curious what X contains? :
#  10.0
# Curious what X contains? :
#  5.0
# Curious what X contains? :
#  2.0
# Curious what X contains? :
#  5.0
# Curious what X contains? :
#  8.0
# Curious what X contains? :
#  7.0
# Curious what X contains? :
#  A
# Curious what X contains? :
#  E
# Curious what X contains? :
#  F
# Curious what X contains? :
#  D
# Curious what X contains? :
#  A
# Curious what X contains? :
#  C
# Curious what X contains? :
#  A
# Curious what X contains? :
#  A
# Curious what X contains? :
#  D
# Curious what X contains? :
#  E
# Curious what X contains? :
#  C
# Curious what X contains? :
#  B
# Curious what X contains? :
#  O
# Curious what X contains? :
#  F
# Curious what X contains? :
#  B
# Curious what X contains? :
#  B
# Curious what X contains? :
#  B
# Curious what X contains? :
#  O
# Curious what X contains? :
#  E
# Curious what X contains? :
#  E
# Curious what X contains? :
#  A
# Curious what X contains? :
#  F
# Curious what X contains? :
#  O
# Curious what X contains? :
#  O
# Curious what X contains? :
#  E
# Curious what X contains? :
#  A
# Curious what X contains? :
#  E
# Curious what X contains? :
#  E
# Curious what X contains? :
#  A
# Curious what X contains? :
#  O
# Curious what X contains? :
#  E
# Curious what X contains? :
#  O
# Curious what X contains? :
#  O
# Curious what X contains? :
#  F
# Curious what X contains? :
#  B
# Curious what X contains? :
#  E
# Curious what X contains? :
#  O
# Curious what X contains? :
#  D
# Curious what X contains? :
#  C
# Curious what X contains? :
#  A
# Curious what X contains? :
#  Nailed it.!
# Curious what X contains? :
#  O
# Curious what X contains? :
#  E
# Curious what X contains? :
#  D
# Curious what X contains? :
#  O
# Curious what X contains? :
#  O
# Curious what X contains? :
#  D
# Curious what X contains? :
#  Nailed it.!
# Curious what X contains? :
#  D
# Curious what X contains? :
#  A
# Curious what X contains? :
#  B
# Curious what X contains? :
#  Name_0
# Curious what X contains? :
#  Name_3
# Curious what X contains? :
#  Name_13
# Curious what X contains? :
#  Name_28
# Curious what X contains? :
#  Name_33
# Curious what X contains? :
#  Name_36
# Curious what X contains? :
#  Name_42
# Curious what X contains? :
#  Name_43
# Curious what X contains? :
#  Name_46
# Curious what X contains? :
#  Name_61
# Curious what X contains? :
#  Name_64
# Curious what X contains? :
#  Name_67
# Curious what X contains? :
#  Name_80
# Curious what X contains? :
#  Name_86
# Curious what X contains? :
#  Name_97
# Curious what X contains? :
#  Name_104
# Curious what X contains? :
#  Name_110
# Curious what X contains? :
#  Name_120
# Curious what X contains? :
#  Name_123
# Curious what X contains? :
#  Name_125
# Curious what X contains? :
#  Name_126
# Curious what X contains? :
#  Name_136
# Curious what X contains? :
#  Name_137
# Curious what X contains? :
#  Name_141
# Curious what X contains? :
#  Name_145
# Curious what X contains? :
#  Name_149
# Curious what X contains? :
#  Name_168
# Curious what X contains? :
#  Name_179
# Curious what X contains? :
#  Name_187
# Curious what X contains? :
#  Name_188
# Curious what X contains? :
#  Name_199
# Curious what X contains? :
#  Name_204
# Curious what X contains? :
#  Name_206
# Curious what X contains? :
#  Name_208
# Curious what X contains? :
#  Name_213
# Curious what X contains? :
#  Name_215
# Curious what X contains? :
#  Name_224
# Curious what X contains? :
#  Name_225
# Curious what X contains? :
#  Name_227
# Curious what X contains? :
#  Name_233
# Curious what X contains? :
#  Name_234
# Curious what X contains? :
#  Name_242
# Curious what X contains? :
#  Name_250
# Curious what X contains? :
#  Name_253
# Curious what X contains? :
#  Name_255
# Curious what X contains? :
#  Name_261
# Curious what X contains? :
#  Name_268
# Curious what X contains? :
#  Name_272
# Curious what X contains? :
#  Name_276
# Curious what X contains? :
#  Name_282
# Curious what X contains? :
#  Name_287
# Curious what X contains? :
#  Name_298
# Curious what X contains? :
#  Subject_1
# Curious what X contains? :
#  Subject_1
# Curious what X contains? :
#  Subject_1
# Curious what X contains? :
#  Subject_1
# Curious what X contains? :
#  Subject_1
# Curious what X contains? :
#  Subject_1
# Curious what X contains? :
#  Subject_1
# Curious what X contains? :
#  Subject_1
# Curious what X contains? :
#  Subject_1
# Curious what X contains? :
#  Subject_1
# Curious what X contains? :
#  Subject_1
# Curious what X contains? :
#  Subject_1
# Curious what X contains? :
#  Subject_1
# Curious what X contains? :
#  Subject_1
# Curious what X contains? :
#  Subject_1
# Curious what X contains? :
#  Subject_1
# Curious what X contains? :
#  Subject_1
# Curious what X contains? :
#  Subject_1
# Curious what X contains? :
#  Subject_1
# Curious what X contains? :
#  Subject_1
# Curious what X contains? :
#  Subject_1
# Curious what X contains? :
#  Subject_1
# Curious what X contains? :
#  Subject_1
# Curious what X contains? :
#  Subject_1
# Curious what X contains? :
#  Subject_1
# Curious what X contains? :
#  Subject_1
# Curious what X contains? :
#  Subject_1
# Curious what X contains? :
#  Subject_1
# Curious what X contains? :
#  Subject_1
# Curious what X contains? :
#  Subject_1
# Curious what X contains? :
#  Subject_1
# Curious what X contains? :
#  Subject_1
# Curious what X contains? :
#  Subject_1
# Curious what X contains? :
#  Subject_1
# Curious what X contains? :
#  Subject_1
# Curious what X contains? :
#  Subject_1
# Curious what X contains? :
#  Subject_1
# Curious what X contains? :
#  Subject_1
# Curious what X contains? :
#  Subject_1
# Curious what X contains? :
#  Subject_1
# Curious what X contains? :
#  Subject_1
# Curious what X contains? :
#  Subject_1
# Curious what X contains? :
#  Subject_1
# Curious what X contains? :
#  Subject_1
# Curious what X contains? :
#  Subject_1
# Curious what X contains? :
#  Subject_1
# Curious what X contains? :
#  Subject_1
# Curious what X contains? :
#  Subject_1
# Curious what X contains? :
#  Subject_1
# Curious what X contains? :
#  Subject_1
# Curious what X contains? :
#  Subject_1
# Curious what X contains? :
#  Subject_1
# Curious what X contains? :
#  2.1068655162078356
# Curious what X contains? :
#  1.6331200626721305
# Curious what X contains? :
#  3.0889456570133906
# Curious what X contains? :
#  7.573858541538917
# Curious what X contains? :
#  3.3686511234564476
# Curious what X contains? :
#  3.7502694138562793
# Curious what X contains? :
#  2.2036761788996406
# Curious what X contains? :
#  6.440164039008311
# Curious what X contains? :
#  7.744461200269511
# Curious what X contains? :
#  3.0837533777674206
# Curious what X contains? :
#  4.424973510128771
# Curious what X contains? :
#  3.584228792641677
# Curious what X contains? :
#  3.6061406163622154
# Curious what X contains? :
#  5.3123185068951075
# Curious what X contains? :
#  9.047779383388235
# Curious what X contains? :
#  8.351898373293677
# Curious what X contains? :
#  7.080623111825618
# Curious what X contains? :
#  2.134556320388893
# Curious what X contains? :
#  2.8399945108095075
# Curious what X contains? :
#  7.325128933577857
# Curious what X contains? :
#  7.466574372763468
# Curious what X contains? :
#  9.48083270898922
# Curious what X contains? :
#  2.003286061974925
# Curious what X contains? :
#  4.318042592656702
# Curious what X contains? :
#  9.265543461993255
# Curious what X contains? :
#  8.794317224278895
# Curious what X contains? :
#  6.1569021486724225
# Curious what X contains? :
#  9.560860575774981
# Curious what X contains? :
#  5.081949446877964
# Curious what X contains? :
#  9.730552007391584
# Curious what X contains? :
#  4.326941123193984
# Curious what X contains? :
#  9.684602194985619
# Curious what X contains? :
#  9.36846961979294
# Curious what X contains? :
#  2.737805888085635
# Curious what X contains? :
#  7.298804229234439
# Curious what X contains? :
#  7.755029880073689
# Curious what X contains? :
#  5.7397175623004415
# Curious what X contains? :
#  2.1894037737700485
# Curious what X contains? :
#  6.45865849555304
# Curious what X contains? :
#  7.30707941373347
# Curious what X contains? :
#  7.681638921131361
# Curious what X contains? :
#  1.7264465642850575
# Curious what X contains? :
#  9.740035114834262
# Curious what X contains? :
#  9.890786499147861
# Curious what X contains? :
#  6.898740274113512
# Curious what X contains? :
#  2.8247173444624427
# Curious what X contains? :
#  2.541817634010311
# Curious what X contains? :
#  6.729728114037039
# Curious what X contains? :
#  5.448140634522663
# Curious what X contains? :
#  5.895073279950148
# Curious what X contains? :
#  1.2082889793544624
# Curious what X contains? :
#  1.9762734155590813
# Curious what X contains? :
#  3.0
# Curious what X contains? :
#  2.0
# Curious what X contains? :
#  4.0
# Curious what X contains? :
#  8.0
# Curious what X contains? :
#  4.0
# Curious what X contains? :
#  4.0
# Curious what X contains? :
#  3.0
# Curious what X contains? :
#  7.0
# Curious what X contains? :
#  8.0
# Curious what X contains? :
#  4.0
# Curious what X contains? :
#  5.0
# Curious what X contains? :
#  4.0
# Curious what X contains? :
#  4.0
# Curious what X contains? :
#  6.0
# Curious what X contains? :
#  10.0
# Curious what X contains? :
#  9.0
# Curious what X contains? :
#  8.0
# Curious what X contains? :
#  3.0
# Curious what X contains? :
#  3.0
# Curious what X contains? :
#  8.0
# Curious what X contains? :
#  8.0
# Curious what X contains? :
#  10.0
# Curious what X contains? :
#  3.0
# Curious what X contains? :
#  5.0
# Curious what X contains? :
#  10.0
# Curious what X contains? :
#  9.0
# Curious what X contains? :
#  7.0
# Curious what X contains? :
#  10.0
# Curious what X contains? :
#  6.0
# Curious what X contains? :
#  10.0
# Curious what X contains? :
#  5.0
# Curious what X contains? :
#  10.0
# Curious what X contains? :
#  10.0
# Curious what X contains? :
#  3.0
# Curious what X contains? :
#  8.0
# Curious what X contains? :
#  8.0
# Curious what X contains? :
#  6.0
# Curious what X contains? :
#  3.0
# Curious what X contains? :
#  7.0
# Curious what X contains? :
#  8.0
# Curious what X contains? :
#  8.0
# Curious what X contains? :
#  2.0
# Curious what X contains? :
#  10.0
# Curious what X contains? :
#  10.0
# Curious what X contains? :
#  7.0
# Curious what X contains? :
#  3.0
# Curious what X contains? :
#  3.0
# Curious what X contains? :
#  7.0
# Curious what X contains? :
#  6.0
# Curious what X contains? :
#  6.0
# Curious what X contains? :
#  2.0
# Curious what X contains? :
#  2.0
# Curious what X contains? :
#  F
# Curious what X contains? :
#  Nailed it.!
# Curious what X contains? :
#  E
# Curious what X contains? :
#  A
# Curious what X contains? :
#  E
# Curious what X contains? :
#  E
# Curious what X contains? :
#  F
# Curious what X contains? :
#  B
# Curious what X contains? :
#  A
# Curious what X contains? :
#  E
# Curious what X contains? :
#  D
# Curious what X contains? :
#  E
# Curious what X contains? :
#  E
# Curious what X contains? :
#  C
# Curious what X contains? :
#  O
# Curious what X contains? :
#  E
# Curious what X contains? :
#  A
# Curious what X contains? :
#  F
# Curious what X contains? :
#  F
# Curious what X contains? :
#  A
# Curious what X contains? :
#  A
# Curious what X contains? :
#  O
# Curious what X contains? :
#  F
# Curious what X contains? :
#  D
# Curious what X contains? :
#  O
# Curious what X contains? :
#  E
# Curious what X contains? :
#  B
# Curious what X contains? :
#  O
# Curious what X contains? :
#  C
# Curious what X contains? :
#  O
# Curious what X contains? :
#  D
# Curious what X contains? :
#  O
# Curious what X contains? :
#  O
# Curious what X contains? :
#  F
# Curious what X contains? :
#  A
# Curious what X contains? :
#  A
# Curious what X contains? :
#  C
# Curious what X contains? :
#  F
# Curious what X contains? :
#  B
# Curious what X contains? :
#  A
# Curious what X contains? :
#  A
# Curious what X contains? :
#  Nailed it.!
# Curious what X contains? :
#  O
# Curious what X contains? :
#  O
# Curious what X contains? :
#  B
# Curious what X contains? :
#  F
# Curious what X contains? :
#  F
# Curious what X contains? :
#  B
# Curious what X contains? :
#  C
# Curious what X contains? :
#  C
# Curious what X contains? :
#  Nailed it.!
# Curious what X contains? :
#  Nailed it.!
# Curious what X contains? :
#  Name_5
# Curious what X contains? :
#  Name_6
# Curious what X contains? :
#  Name_9
# Curious what X contains? :
#  Name_12
# Curious what X contains? :
#  Name_23
# Curious what X contains? :
#  Name_25
# Curious what X contains? :
#  Name_31
# Curious what X contains? :
#  Name_38
# Curious what X contains? :
#  Name_45
# Curious what X contains? :
#  Name_48
# Curious what X contains? :
#  Name_81
# Curious what X contains? :
#  Name_83
# Curious what X contains? :
#  Name_89
# Curious what X contains? :
#  Name_90
# Curious what X contains? :
#  Name_91
# Curious what X contains? :
#  Name_94
# Curious what X contains? :
#  Name_105
# Curious what X contains? :
#  Name_112
# Curious what X contains? :
#  Name_118
# Curious what X contains? :
#  Name_130
# Curious what X contains? :
#  Name_131
# Curious what X contains? :
#  Name_143
# Curious what X contains? :
#  Name_154
# Curious what X contains? :
#  Name_156
# Curious what X contains? :
#  Name_158
# Curious what X contains? :
#  Name_172
# Curious what X contains? :
#  Name_174
# Curious what X contains? :
#  Name_176
# Curious what X contains? :
#  Name_181
# Curious what X contains? :
#  Name_189
# Curious what X contains? :
#  Name_191
# Curious what X contains? :
#  Name_195
# Curious what X contains? :
#  Name_196
# Curious what X contains? :
#  Name_197
# Curious what X contains? :
#  Name_205
# Curious what X contains? :
#  Name_209
# Curious what X contains? :
#  Name_210
# Curious what X contains? :
#  Name_211
# Curious what X contains? :
#  Name_214
# Curious what X contains? :
#  Name_231
# Curious what X contains? :
#  Name_237
# Curious what X contains? :
#  Name_241
# Curious what X contains? :
#  Name_246
# Curious what X contains? :
#  Name_275
# Curious what X contains? :
#  Name_277
# Curious what X contains? :
#  Name_278
# Curious what X contains? :
#  Name_279
# Curious what X contains? :
#  Name_285
# Curious what X contains? :
#  Name_297
# Curious what X contains? :
#  Subject_2
# Curious what X contains? :
#  Subject_2
# Curious what X contains? :
#  Subject_2
# Curious what X contains? :
#  Subject_2
# Curious what X contains? :
#  Subject_2
# Curious what X contains? :
#  Subject_2
# Curious what X contains? :
#  Subject_2
# Curious what X contains? :
#  Subject_2
# Curious what X contains? :
#  Subject_2
# Curious what X contains? :
#  Subject_2
# Curious what X contains? :
#  Subject_2
# Curious what X contains? :
#  Subject_2
# Curious what X contains? :
#  Subject_2
# Curious what X contains? :
#  Subject_2
# Curious what X contains? :
#  Subject_2
# Curious what X contains? :
#  Subject_2
# Curious what X contains? :
#  Subject_2
# Curious what X contains? :
#  Subject_2
# Curious what X contains? :
#  Subject_2
# Curious what X contains? :
#  Subject_2
# Curious what X contains? :
#  Subject_2
# Curious what X contains? :
#  Subject_2
# Curious what X contains? :
#  Subject_2
# Curious what X contains? :
#  Subject_2
# Curious what X contains? :
#  Subject_2
# Curious what X contains? :
#  Subject_2
# Curious what X contains? :
#  Subject_2
# Curious what X contains? :
#  Subject_2
# Curious what X contains? :
#  Subject_2
# Curious what X contains? :
#  Subject_2
# Curious what X contains? :
#  Subject_2
# Curious what X contains? :
#  Subject_2
# Curious what X contains? :
#  Subject_2
# Curious what X contains? :
#  Subject_2
# Curious what X contains? :
#  Subject_2
# Curious what X contains? :
#  Subject_2
# Curious what X contains? :
#  Subject_2
# Curious what X contains? :
#  Subject_2
# Curious what X contains? :
#  Subject_2
# Curious what X contains? :
#  Subject_2
# Curious what X contains? :
#  Subject_2
# Curious what X contains? :
#  Subject_2
# Curious what X contains? :
#  Subject_2
# Curious what X contains? :
#  Subject_2
# Curious what X contains? :
#  Subject_2
# Curious what X contains? :
#  Subject_2
# Curious what X contains? :
#  Subject_2
# Curious what X contains? :
#  Subject_2
# Curious what X contains? :
#  Subject_2
# Curious what X contains? :
#  3.121444130836327
# Curious what X contains? :
#  1.9284775287497142
# Curious what X contains? :
#  6.895104359379735
# Curious what X contains? :
#  9.126247575835448
# Curious what X contains? :
#  3.3076805266563927
# Curious what X contains? :
#  8.947460325319213
# Curious what X contains? :
#  1.718055398422102
# Curious what X contains? :
#  6.21792888076778
# Curious what X contains? :
#  8.553726461728019
# Curious what X contains? :
#  2.038327474183034
# Curious what X contains? :
#  7.374735632266931
# Curious what X contains? :
#  2.8241492634596055
# Curious what X contains? :
#  5.909298666702256
# Curious what X contains? :
#  7.200160508369718
# Curious what X contains? :
#  3.8802103238708803
# Curious what X contains? :
#  9.469249416705377
# Curious what X contains? :
#  8.926832755953196
# Curious what X contains? :
#  5.7766017322512155
# Curious what X contains? :
#  5.121304580109072
# Curious what X contains? :
#  6.394056828304361
# Curious what X contains? :
#  9.73675781419413
# Curious what X contains? :
#  9.2121615863149
# Curious what X contains? :
#  1.8689011134248352
# Curious what X contains? :
#  3.627359210335881
# Curious what X contains? :
#  3.557851701738964
# Curious what X contains? :
#  9.4718990120978
# Curious what X contains? :
#  9.777260303012053
# Curious what X contains? :
#  4.545980624918881
# Curious what X contains? :
#  5.685366610379952
# Curious what X contains? :
#  6.276706163760484
# Curious what X contains? :
#  8.122015034039142
# Curious what X contains? :
#  3.957759392278882
# Curious what X contains? :
#  8.198389000961562
# Curious what X contains? :
#  7.837482975957134
# Curious what X contains? :
#  1.505094897483679
# Curious what X contains? :
#  5.849254261379874
# Curious what X contains? :
#  7.4109357989835045
# Curious what X contains? :
#  8.811792330487545
# Curious what X contains? :
#  1.2131807646146513
# Curious what X contains? :
#  7.531170436718892
# Curious what X contains? :
#  6.461979988516526
# Curious what X contains? :
#  4.609770092493337
# Curious what X contains? :
#  5.945205226007276
# Curious what X contains? :
#  3.590838953583676
# Curious what X contains? :
#  4.250739748564784
# Curious what X contains? :
#  6.948049726698119
# Curious what X contains? :
#  7.249246559676459
# Curious what X contains? :
#  3.5039874825491455
# Curious what X contains? :
#  9.824163820822799
# Curious what X contains? :
#  4.0
# Curious what X contains? :
#  2.0
# Curious what X contains? :
#  7.0
# Curious what X contains? :
#  10.0
# Curious what X contains? :
#  4.0
# Curious what X contains? :
#  9.0
# Curious what X contains? :
#  2.0
# Curious what X contains? :
#  7.0
# Curious what X contains? :
#  9.0
# Curious what X contains? :
#  3.0
# Curious what X contains? :
#  8.0
# Curious what X contains? :
#  3.0
# Curious what X contains? :
#  6.0
# Curious what X contains? :
#  8.0
# Curious what X contains? :
#  4.0
# Curious what X contains? :
#  10.0
# Curious what X contains? :
#  9.0
# Curious what X contains? :
#  6.0
# Curious what X contains? :
#  6.0
# Curious what X contains? :
#  7.0
# Curious what X contains? :
#  10.0
# Curious what X contains? :
#  10.0
# Curious what X contains? :
#  2.0
# Curious what X contains? :
#  4.0
# Curious what X contains? :
#  4.0
# Curious what X contains? :
#  10.0
# Curious what X contains? :
#  10.0
# Curious what X contains? :
#  5.0
# Curious what X contains? :
#  6.0
# Curious what X contains? :
#  7.0
# Curious what X contains? :
#  9.0
# Curious what X contains? :
#  4.0
# Curious what X contains? :
#  9.0
# Curious what X contains? :
#  8.0
# Curious what X contains? :
#  2.0
# Curious what X contains? :
#  6.0
# Curious what X contains? :
#  8.0
# Curious what X contains? :
#  9.0
# Curious what X contains? :
#  2.0
# Curious what X contains? :
#  8.0
# Curious what X contains? :
#  7.0
# Curious what X contains? :
#  5.0
# Curious what X contains? :
#  6.0
# Curious what X contains? :
#  4.0
# Curious what X contains? :
#  5.0
# Curious what X contains? :
#  7.0
# Curious what X contains? :
#  8.0
# Curious what X contains? :
#  4.0
# Curious what X contains? :
#  10.0
# Curious what X contains? :
#  E
# Curious what X contains? :
#  Nailed it.!
# Curious what X contains? :
#  B
# Curious what X contains? :
#  O
# Curious what X contains? :
#  E
# Curious what X contains? :
#  E
# Curious what X contains? :
#  Nailed it.!
# Curious what X contains? :
#  B
# Curious what X contains? :
#  E
# Curious what X contains? :
#  F
# Curious what X contains? :
#  A
# Curious what X contains? :
#  F
# Curious what X contains? :
#  C
# Curious what X contains? :
#  A
# Curious what X contains? :
#  E
# Curious what X contains? :
#  O
# Curious what X contains? :
#  E
# Curious what X contains? :
#  C
# Curious what X contains? :
#  C
# Curious what X contains? :
#  B
# Curious what X contains? :
#  O
# Curious what X contains? :
#  O
# Curious what X contains? :
#  Nailed it.!
# Curious what X contains? :
#  E
# Curious what X contains? :
#  E
# Curious what X contains? :
#  O
# Curious what X contains? :
#  O
# Curious what X contains? :
#  D
# Curious what X contains? :
#  C
# Curious what X contains? :
#  B
# Curious what X contains? :
#  E
# Curious what X contains? :
#  E
# Curious what X contains? :
#  E
# Curious what X contains? :
#  A
# Curious what X contains? :
#  Nailed it.!
# Curious what X contains? :
#  C
# Curious what X contains? :
#  A
# Curious what X contains? :
#  E
# Curious what X contains? :
#  Nailed it.!
# Curious what X contains? :
#  A
# Curious what X contains? :
#  B
# Curious what X contains? :
#  D
# Curious what X contains? :
#  C
# Curious what X contains? :
#  E
# Curious what X contains? :
#  D
# Curious what X contains? :
#  B
# Curious what X contains? :
#  A
# Curious what X contains? :
#  E
# Curious what X contains? :
#  O
# Curious what X contains? :
#  Name_15
# Curious what X contains? :
#  Name_19
# Curious what X contains? :
#  Name_24
# Curious what X contains? :
#  Name_29
# Curious what X contains? :
#  Name_30
# Curious what X contains? :
#  Name_34
# Curious what X contains? :
#  Name_35
# Curious what X contains? :
#  Name_39
# Curious what X contains? :
#  Name_41
# Curious what X contains? :
#  Name_51
# Curious what X contains? :
#  Name_52
# Curious what X contains? :
#  Name_73
# Curious what X contains? :
#  Name_75
# Curious what X contains? :
#  Name_77
# Curious what X contains? :
#  Name_85
# Curious what X contains? :
#  Name_95
# Curious what X contains? :
#  Name_99
# Curious what X contains? :
#  Name_102
# Curious what X contains? :
#  Name_113
# Curious what X contains? :
#  Name_114
# Curious what X contains? :
#  Name_127
# Curious what X contains? :
#  Name_138
# Curious what X contains? :
#  Name_147
# Curious what X contains? :
#  Name_164
# Curious what X contains? :
#  Name_165
# Curious what X contains? :
#  Name_170
# Curious what X contains? :
#  Name_178
# Curious what X contains? :
#  Name_180
# Curious what X contains? :
#  Name_183
# Curious what X contains? :
#  Name_185
# Curious what X contains? :
#  Name_186
# Curious what X contains? :
#  Name_200
# Curious what X contains? :
#  Name_207
# Curious what X contains? :
#  Name_220
# Curious what X contains? :
#  Name_221
# Curious what X contains? :
#  Name_222
# Curious what X contains? :
#  Name_244
# Curious what X contains? :
#  Name_249
# Curious what X contains? :
#  Name_251
# Curious what X contains? :
#  Name_256
# Curious what X contains? :
#  Name_260
# Curious what X contains? :
#  Name_263
# Curious what X contains? :
#  Name_265
# Curious what X contains? :
#  Name_269
# Curious what X contains? :
#  Name_270
# Curious what X contains? :
#  Name_271
# Curious what X contains? :
#  Name_283
# Curious what X contains? :
#  Name_288
# Curious what X contains? :
#  Name_292
# Curious what X contains? :
#  Name_294
# Curious what X contains? :
#  Name_296
# Curious what X contains? :
#  Name_299
# Curious what X contains? :
#  Subject_3
# Curious what X contains? :
#  Subject_3
# Curious what X contains? :
#  Subject_3
# Curious what X contains? :
#  Subject_3
# Curious what X contains? :
#  Subject_3
# Curious what X contains? :
#  Subject_3
# Curious what X contains? :
#  Subject_3
# Curious what X contains? :
#  Subject_3
# Curious what X contains? :
#  Subject_3
# Curious what X contains? :
#  Subject_3
# Curious what X contains? :
#  Subject_3
# Curious what X contains? :
#  Subject_3
# Curious what X contains? :
#  Subject_3
# Curious what X contains? :
#  Subject_3
# Curious what X contains? :
#  Subject_3
# Curious what X contains? :
#  Subject_3
# Curious what X contains? :
#  Subject_3
# Curious what X contains? :
#  Subject_3
# Curious what X contains? :
#  Subject_3
# Curious what X contains? :
#  Subject_3
# Curious what X contains? :
#  Subject_3
# Curious what X contains? :
#  Subject_3
# Curious what X contains? :
#  Subject_3
# Curious what X contains? :
#  Subject_3
# Curious what X contains? :
#  Subject_3
# Curious what X contains? :
#  Subject_3
# Curious what X contains? :
#  Subject_3
# Curious what X contains? :
#  Subject_3
# Curious what X contains? :
#  Subject_3
# Curious what X contains? :
#  Subject_3
# Curious what X contains? :
#  Subject_3
# Curious what X contains? :
#  Subject_3
# Curious what X contains? :
#  Subject_3
# Curious what X contains? :
#  Subject_3
# Curious what X contains? :
#  Subject_3
# Curious what X contains? :
#  Subject_3
# Curious what X contains? :
#  Subject_3
# Curious what X contains? :
#  Subject_3
# Curious what X contains? :
#  Subject_3
# Curious what X contains? :
#  Subject_3
# Curious what X contains? :
#  Subject_3
# Curious what X contains? :
#  Subject_3
# Curious what X contains? :
#  Subject_3
# Curious what X contains? :
#  Subject_3
# Curious what X contains? :
#  Subject_3
# Curious what X contains? :
#  Subject_3
# Curious what X contains? :
#  Subject_3
# Curious what X contains? :
#  Subject_3
# Curious what X contains? :
#  Subject_3
# Curious what X contains? :
#  Subject_3
# Curious what X contains? :
#  Subject_3
# Curious what X contains? :
#  Subject_3
# Curious what X contains? :
#  9.810747888377897
# Curious what X contains? :
#  3.050142714664589
# Curious what X contains? :
#  7.025708161571291
# Curious what X contains? :
#  3.654001076598285
# Curious what X contains? :
#  4.5598303495916035
# Curious what X contains? :
#  4.711553830504573
# Curious what X contains? :
#  1.8917154908396834
# Curious what X contains? :
#  6.0073815326261375
# Curious what X contains? :
#  9.684943372679692
# Curious what X contains? :
#  4.287186216953784
# Curious what X contains? :
#  3.297941254099855
# Curious what X contains? :
#  9.02763702643877
# Curious what X contains? :
#  7.950031806579698
# Curious what X contains? :
#  8.762771990004032
# Curious what X contains? :
#  2.4371125253582306
# Curious what X contains? :
#  2.8089063293716965
# Curious what X contains? :
#  2.4526146145586463
# Curious what X contains? :
#  8.99172970646787
# Curious what X contains? :
#  2.9400784367838773
# Curious what X contains? :
#  8.898470341008077
# Curious what X contains? :
#  6.859756735794876
# Curious what X contains? :
#  9.791242933065968
# Curious what X contains? :
#  7.498773519766101
# Curious what X contains? :
#  5.4761051457809335
# Curious what X contains? :
#  3.345961302412638
# Curious what X contains? :
#  8.260940288498972
# Curious what X contains? :
#  9.423925842648735
# Curious what X contains? :
#  7.863098119950552
# Curious what X contains? :
#  1.0232299769839592
# Curious what X contains? :
#  4.726962062535514
# Curious what X contains? :
#  3.391623032873535
# Curious what X contains? :
#  4.339955188475804
# Curious what X contains? :
#  6.837184075919746
# Curious what X contains? :
#  7.975241343825552
# Curious what X contains? :
#  2.693657908984598
# Curious what X contains? :
#  5.691726603692417
# Curious what X contains? :
#  2.9129764980676
# Curious what X contains? :
#  3.5474581603877846
# Curious what X contains? :
#  4.273799154349658
# Curious what X contains? :
#  4.197011754890305
# Curious what X contains? :
#  4.549924894205085
# Curious what X contains? :
#  7.2405711238943
# Curious what X contains? :
#  2.7581090796916343
# Curious what X contains? :
#  5.014825035371129
# Curious what X contains? :
#  3.6754735739527424
# Curious what X contains? :
#  1.7782624879877005
# Curious what X contains? :
#  7.611568806670599
# Curious what X contains? :
#  6.869682276913325
# Curious what X contains? :
#  3.9309973234421025
# Curious what X contains? :
#  2.8622356736388035
# Curious what X contains? :
#  9.627529283886263
# Curious what X contains? :
#  9.246433929489632
# Curious what X contains? :
#  10.0
# Curious what X contains? :
#  4.0
# Curious what X contains? :
#  8.0
# Curious what X contains? :
#  4.0
# Curious what X contains? :
#  5.0
# Curious what X contains? :
#  5.0
# Curious what X contains? :
#  2.0
# Curious what X contains? :
#  7.0
# Curious what X contains? :
#  10.0
# Curious what X contains? :
#  5.0
# Curious what X contains? :
#  4.0
# Curious what X contains? :
#  10.0
# Curious what X contains? :
#  8.0
# Curious what X contains? :
#  9.0
# Curious what X contains? :
#  3.0
# Curious what X contains? :
#  3.0
# Curious what X contains? :
#  3.0
# Curious what X contains? :
#  9.0
# Curious what X contains? :
#  3.0
# Curious what X contains? :
#  9.0
# Curious what X contains? :
#  7.0
# Curious what X contains? :
#  10.0
# Curious what X contains? :
#  8.0
# Curious what X contains? :
#  6.0
# Curious what X contains? :
#  4.0
# Curious what X contains? :
#  9.0
# Curious what X contains? :
#  10.0
# Curious what X contains? :
#  8.0
# Curious what X contains? :
#  2.0
# Curious what X contains? :
#  5.0
# Curious what X contains? :
#  4.0
# Curious what X contains? :
#  5.0
# Curious what X contains? :
#  7.0
# Curious what X contains? :
#  8.0
# Curious what X contains? :
#  3.0
# Curious what X contains? :
#  6.0
# Curious what X contains? :
#  3.0
# Curious what X contains? :
#  4.0
# Curious what X contains? :
#  5.0
# Curious what X contains? :
#  5.0
# Curious what X contains? :
#  5.0
# Curious what X contains? :
#  8.0
# Curious what X contains? :
#  3.0
# Curious what X contains? :
#  6.0
# Curious what X contains? :
#  4.0
# Curious what X contains? :
#  2.0
# Curious what X contains? :
#  8.0
# Curious what X contains? :
#  7.0
# Curious what X contains? :
#  4.0
# Curious what X contains? :
#  3.0
# Curious what X contains? :
#  10.0
# Curious what X contains? :
#  10.0
# Curious what X contains? :
#  O
# Curious what X contains? :
#  E
# Curious what X contains? :
#  A
# Curious what X contains? :
#  E
# Curious what X contains? :
#  D
# Curious what X contains? :
#  D
# Curious what X contains? :
#  Nailed it.!
# Curious what X contains? :
#  B
# Curious what X contains? :
#  O
# Curious what X contains? :
#  D
# Curious what X contains? :
#  E
# Curious what X contains? :
#  O
# Curious what X contains? :
#  A
# Curious what X contains? :
#  E
# Curious what X contains? :
#  F
# Curious what X contains? :
#  F
# Curious what X contains? :
#  F
# Curious what X contains? :
#  E
# Curious what X contains? :
#  F
# Curious what X contains? :
#  E
# Curious what X contains? :
#  B
# Curious what X contains? :
#  O
# Curious what X contains? :
#  A
# Curious what X contains? :
#  C
# Curious what X contains? :
#  E
# Curious what X contains? :
#  E
# Curious what X contains? :
#  O
# Curious what X contains? :
#  A
# Curious what X contains? :
#  Nailed it.!
# Curious what X contains? :
#  D
# Curious what X contains? :
#  E
# Curious what X contains? :
#  D
# Curious what X contains? :
#  B
# Curious what X contains? :
#  A
# Curious what X contains? :
#  F
# Curious what X contains? :
#  C
# Curious what X contains? :
#  F
# Curious what X contains? :
#  E
# Curious what X contains? :
#  D
# Curious what X contains? :
#  D
# Curious what X contains? :
#  D
# Curious what X contains? :
#  A
# Curious what X contains? :
#  F
# Curious what X contains? :
#  C
# Curious what X contains? :
#  E
# Curious what X contains? :
#  Nailed it.!
# Curious what X contains? :
#  A
# Curious what X contains? :
#  B
# Curious what X contains? :
#  E
# Curious what X contains? :
#  F
# Curious what X contains? :
#  O
# Curious what X contains? :
#  O
# Curious what X contains? :
#  Name_7
# Curious what X contains? :
#  Name_10
# Curious what X contains? :
#  Name_11
# Curious what X contains? :
#  Name_14
# Curious what X contains? :
#  Name_21
# Curious what X contains? :
#  Name_37
# Curious what X contains? :
#  Name_44
# Curious what X contains? :
#  Name_55
# Curious what X contains? :
#  Name_57
# Curious what X contains? :
#  Name_59
# Curious what X contains? :
#  Name_60
# Curious what X contains? :
#  Name_62
# Curious what X contains? :
#  Name_65
# Curious what X contains? :
#  Name_69
# Curious what X contains? :
#  Name_71
# Curious what X contains? :
#  Name_76
# Curious what X contains? :
#  Name_79
# Curious what X contains? :
#  Name_87
# Curious what X contains? :
#  Name_93
# Curious what X contains? :
#  Name_96
# Curious what X contains? :
#  Name_98
# Curious what X contains? :
#  Name_100
# Curious what X contains? :
#  Name_106
# Curious what X contains? :
#  Name_108
# Curious what X contains? :
#  Name_111
# Curious what X contains? :
#  Name_128
# Curious what X contains? :
#  Name_133
# Curious what X contains? :
#  Name_134
# Curious what X contains? :
#  Name_135
# Curious what X contains? :
#  Name_140
# Curious what X contains? :
#  Name_148
# Curious what X contains? :
#  Name_153
# Curious what X contains? :
#  Name_161
# Curious what X contains? :
#  Name_166
# Curious what X contains? :
#  Name_167
# Curious what X contains? :
#  Name_169
# Curious what X contains? :
#  Name_177
# Curious what X contains? :
#  Name_192
# Curious what X contains? :
#  Name_202
# Curious what X contains? :
#  Name_212
# Curious what X contains? :
#  Name_217
# Curious what X contains? :
#  Name_226
# Curious what X contains? :
#  Name_232
# Curious what X contains? :
#  Name_235
# Curious what X contains? :
#  Name_238
# Curious what X contains? :
#  Name_240
# Curious what X contains? :
#  Name_243
# Curious what X contains? :
#  Name_247
# Curious what X contains? :
#  Name_248
# Curious what X contains? :
#  Name_258
# Curious what X contains? :
#  Name_259
# Curious what X contains? :
#  Name_266
# Curious what X contains? :
#  Name_267
# Curious what X contains? :
#  Name_273
# Curious what X contains? :
#  Name_274
# Curious what X contains? :
#  Name_289
# Curious what X contains? :
#  Subject_4
# Curious what X contains? :
#  Subject_4
# Curious what X contains? :
#  Subject_4
# Curious what X contains? :
#  Subject_4
# Curious what X contains? :
#  Subject_4
# Curious what X contains? :
#  Subject_4
# Curious what X contains? :
#  Subject_4
# Curious what X contains? :
#  Subject_4
# Curious what X contains? :
#  Subject_4
# Curious what X contains? :
#  Subject_4
# Curious what X contains? :
#  Subject_4
# Curious what X contains? :
#  Subject_4
# Curious what X contains? :
#  Subject_4
# Curious what X contains? :
#  Subject_4
# Curious what X contains? :
#  Subject_4
# Curious what X contains? :
#  Subject_4
# Curious what X contains? :
#  Subject_4
# Curious what X contains? :
#  Subject_4
# Curious what X contains? :
#  Subject_4
# Curious what X contains? :
#  Subject_4
# Curious what X contains? :
#  Subject_4
# Curious what X contains? :
#  Subject_4
# Curious what X contains? :
#  Subject_4
# Curious what X contains? :
#  Subject_4
# Curious what X contains? :
#  Subject_4
# Curious what X contains? :
#  Subject_4
# Curious what X contains? :
#  Subject_4
# Curious what X contains? :
#  Subject_4
# Curious what X contains? :
#  Subject_4
# Curious what X contains? :
#  Subject_4
# Curious what X contains? :
#  Subject_4
# Curious what X contains? :
#  Subject_4
# Curious what X contains? :
#  Subject_4
# Curious what X contains? :
#  Subject_4
# Curious what X contains? :
#  Subject_4
# Curious what X contains? :
#  Subject_4
# Curious what X contains? :
#  Subject_4
# Curious what X contains? :
#  Subject_4
# Curious what X contains? :
#  Subject_4
# Curious what X contains? :
#  Subject_4
# Curious what X contains? :
#  Subject_4
# Curious what X contains? :
#  Subject_4
# Curious what X contains? :
#  Subject_4
# Curious what X contains? :
#  Subject_4
# Curious what X contains? :
#  Subject_4
# Curious what X contains? :
#  Subject_4
# Curious what X contains? :
#  Subject_4
# Curious what X contains? :
#  Subject_4
# Curious what X contains? :
#  Subject_4
# Curious what X contains? :
#  Subject_4
# Curious what X contains? :
#  Subject_4
# Curious what X contains? :
#  Subject_4
# Curious what X contains? :
#  Subject_4
# Curious what X contains? :
#  Subject_4
# Curious what X contains? :
#  Subject_4
# Curious what X contains? :
#  Subject_4
# Curious what X contains? :
#  1.2480062712809494
# Curious what X contains? :
#  8.954331119848508
# Curious what X contains? :
#  3.964623062213592
# Curious what X contains? :
#  8.951457228111881
# Curious what X contains? :
#  9.574120831184656
# Curious what X contains? :
#  6.358926704578486
# Curious what X contains? :
#  7.427636797957666
# Curious what X contains? :
#  6.974026295875156
# Curious what X contains? :
#  2.949894369280202
# Curious what X contains? :
#  5.039113043291527
# Curious what X contains? :
#  5.309010077254998
# Curious what X contains? :
#  5.321391410614209
# Curious what X contains? :
#  3.776771313478622
# Curious what X contains? :
#  4.707619189984243
# Curious what X contains? :
#  9.16026444302468
# Curious what X contains? :
#  2.531537044305837
# Curious what X contains? :
#  1.8562154014279866
# Curious what X contains? :
#  2.1229914065995326
# Curious what X contains? :
#  7.280980006686784
# Curious what X contains? :
#  4.399699694252239
# Curious what X contains? :
#  8.013976595624928
# Curious what X contains? :
#  7.8318896724018785
# Curious what X contains? :
#  9.145168572876392
# Curious what X contains? :
#  7.966947820068463
# Curious what X contains? :
#  9.794212783555677
# Curious what X contains? :
#  9.58461583737599
# Curious what X contains? :
#  9.478201048370828
# Curious what X contains? :
#  8.934520518151311
# Curious what X contains? :
#  3.7447817354206903
# Curious what X contains? :
#  3.9267043365687337
# Curious what X contains? :
#  9.980813212644463
# Curious what X contains? :
#  4.147343972188933
# Curious what X contains? :
#  3.797501709911792
# Curious what X contains? :
#  1.4740070918980037
# Curious what X contains? :
#  4.603252495816704
# Curious what X contains? :
#  2.921042997921604
# Curious what X contains? :
#  2.4769781731873763
# Curious what X contains? :
#  3.945377648444389
# Curious what X contains? :
#  4.622090919948555
# Curious what X contains? :
#  5.560544341428211
# Curious what X contains? :
#  8.61197388935741
# Curious what X contains? :
#  7.25081559497364
# Curious what X contains? :
#  7.7247601424173755
# Curious what X contains? :
#  3.6262631388719244
# Curious what X contains? :
#  5.842592891709603
# Curious what X contains? :
#  4.212397564805911
# Curious what X contains? :
#  9.153691504944254
# Curious what X contains? :
#  4.709078417917649
# Curious what X contains? :
#  9.15807629419295
# Curious what X contains? :
#  5.700781907434131
# Curious what X contains? :
#  1.8082801661537062
# Curious what X contains? :
#  9.64208725155215
# Curious what X contains? :
#  4.321632726961706
# Curious what X contains? :
#  4.062334042229783
# Curious what X contains? :
#  6.567918922845903
# Curious what X contains? :
#  1.4552633644996478
# Curious what X contains? :
#  2.0
# Curious what X contains? :
#  9.0
# Curious what X contains? :
#  4.0
# Curious what X contains? :
#  9.0
# Curious what X contains? :
#  10.0
# Curious what X contains? :
#  7.0
# Curious what X contains? :
#  8.0
# Curious what X contains? :
#  7.0
# Curious what X contains? :
#  3.0
# Curious what X contains? :
#  6.0
# Curious what X contains? :
#  6.0
# Curious what X contains? :
#  6.0
# Curious what X contains? :
#  4.0
# Curious what X contains? :
#  5.0
# Curious what X contains? :
#  10.0
# Curious what X contains? :
#  3.0
# Curious what X contains? :
#  2.0
# Curious what X contains? :
#  3.0
# Curious what X contains? :
#  8.0
# Curious what X contains? :
#  5.0
# Curious what X contains? :
#  9.0
# Curious what X contains? :
#  8.0
# Curious what X contains? :
#  10.0
# Curious what X contains? :
#  8.0
# Curious what X contains? :
#  10.0
# Curious what X contains? :
#  10.0
# Curious what X contains? :
#  10.0
# Curious what X contains? :
#  9.0
# Curious what X contains? :
#  4.0
# Curious what X contains? :
#  4.0
# Curious what X contains? :
#  10.0
# Curious what X contains? :
#  5.0
# Curious what X contains? :
#  4.0
# Curious what X contains? :
#  2.0
# Curious what X contains? :
#  5.0
# Curious what X contains? :
#  3.0
# Curious what X contains? :
#  3.0
# Curious what X contains? :
#  4.0
# Curious what X contains? :
#  5.0
# Curious what X contains? :
#  6.0
# Curious what X contains? :
#  9.0
# Curious what X contains? :
#  8.0
# Curious what X contains? :
#  8.0
# Curious what X contains? :
#  4.0
# Curious what X contains? :
#  6.0
# Curious what X contains? :
#  5.0
# Curious what X contains? :
#  10.0
# Curious what X contains? :
#  5.0
# Curious what X contains? :
#  10.0
# Curious what X contains? :
#  6.0
# Curious what X contains? :
#  2.0
# Curious what X contains? :
#  10.0
# Curious what X contains? :
#  5.0
# Curious what X contains? :
#  5.0
# Curious what X contains? :
#  7.0
# Curious what X contains? :
#  2.0
# Curious what X contains? :
#  Nailed it.!
# Curious what X contains? :
#  E
# Curious what X contains? :
#  E
# Curious what X contains? :
#  E
# Curious what X contains? :
#  O
# Curious what X contains? :
#  B
# Curious what X contains? :
#  A
# Curious what X contains? :
#  B
# Curious what X contains? :
#  F
# Curious what X contains? :
#  C
# Curious what X contains? :
#  C
# Curious what X contains? :
#  C
# Curious what X contains? :
#  E
# Curious what X contains? :
#  D
# Curious what X contains? :
#  O
# Curious what X contains? :
#  F
# Curious what X contains? :
#  Nailed it.!
# Curious what X contains? :
#  F
# Curious what X contains? :
#  A
# Curious what X contains? :
#  D
# Curious what X contains? :
#  E
# Curious what X contains? :
#  A
# Curious what X contains? :
#  O
# Curious what X contains? :
#  A
# Curious what X contains? :
#  O
# Curious what X contains? :
#  O
# Curious what X contains? :
#  O
# Curious what X contains? :
#  E
# Curious what X contains? :
#  E
# Curious what X contains? :
#  E
# Curious what X contains? :
#  O
# Curious what X contains? :
#  D
# Curious what X contains? :
#  E
# Curious what X contains? :
#  Nailed it.!
# Curious what X contains? :
#  D
# Curious what X contains? :
#  F
# Curious what X contains? :
#  F
# Curious what X contains? :
#  E
# Curious what X contains? :
#  D
# Curious what X contains? :
#  C
# Curious what X contains? :
#  E
# Curious what X contains? :
#  A
# Curious what X contains? :
#  A
# Curious what X contains? :
#  E
# Curious what X contains? :
#  C
# Curious what X contains? :
#  D
# Curious what X contains? :
#  O
# Curious what X contains? :
#  D
# Curious what X contains? :
#  O
# Curious what X contains? :
#  C
# Curious what X contains? :
#  Nailed it.!
# Curious what X contains? :
#  O
# Curious what X contains? :
#  D
# Curious what X contains? :
#  D
# Curious what X contains? :
#  B
# Curious what X contains? :
#  Nailed it.!
# Curious what X contains? :
#  Name_1
# Curious what X contains? :
#  Name_2
# Curious what X contains? :
#  Name_16
# Curious what X contains? :
#  Name_18
# Curious what X contains? :
#  Name_22
# Curious what X contains? :
#  Name_32
# Curious what X contains? :
#  Name_40
# Curious what X contains? :
#  Name_49
# Curious what X contains? :
#  Name_53
# Curious what X contains? :
#  Name_56
# Curious what X contains? :
#  Name_66
# Curious what X contains? :
#  Name_78
# Curious what X contains? :
#  Name_82
# Curious what X contains? :
#  Name_84
# Curious what X contains? :
#  Name_88
# Curious what X contains? :
#  Name_103
# Curious what X contains? :
#  Name_109
# Curious what X contains? :
#  Name_115
# Curious what X contains? :
#  Name_119
# Curious what X contains? :
#  Name_132
# Curious what X contains? :
#  Name_139
# Curious what X contains? :
#  Name_144
# Curious what X contains? :
#  Name_146
# Curious what X contains? :
#  Name_150
# Curious what X contains? :
#  Name_151
# Curious what X contains? :
#  Name_159
# Curious what X contains? :
#  Name_160
# Curious what X contains? :
#  Name_171
# Curious what X contains? :
#  Name_173
# Curious what X contains? :
#  Name_182
# Curious what X contains? :
#  Name_184
# Curious what X contains? :
#  Name_193
# Curious what X contains? :
#  Name_218
# Curious what X contains? :
#  Name_223
# Curious what X contains? :
#  Name_236
# Curious what X contains? :
#  Name_252
# Curious what X contains? :
#  Name_262
# Curious what X contains? :
#  Name_281
# Curious what X contains? :
#  Name_284
# Curious what X contains? :
#  Name_293
# Curious what X contains? :
#  Subject_5
# Curious what X contains? :
#  Subject_5
# Curious what X contains? :
#  Subject_5
# Curious what X contains? :
#  Subject_5
# Curious what X contains? :
#  Subject_5
# Curious what X contains? :
#  Subject_5
# Curious what X contains? :
#  Subject_5
# Curious what X contains? :
#  Subject_5
# Curious what X contains? :
#  Subject_5
# Curious what X contains? :
#  Subject_5
# Curious what X contains? :
#  Subject_5
# Curious what X contains? :
#  Subject_5
# Curious what X contains? :
#  Subject_5
# Curious what X contains? :
#  Subject_5
# Curious what X contains? :
#  Subject_5
# Curious what X contains? :
#  Subject_5
# Curious what X contains? :
#  Subject_5
# Curious what X contains? :
#  Subject_5
# Curious what X contains? :
#  Subject_5
# Curious what X contains? :
#  Subject_5
# Curious what X contains? :
#  Subject_5
# Curious what X contains? :
#  Subject_5
# Curious what X contains? :
#  Subject_5
# Curious what X contains? :
#  Subject_5
# Curious what X contains? :
#  Subject_5
# Curious what X contains? :
#  Subject_5
# Curious what X contains? :
#  Subject_5
# Curious what X contains? :
#  Subject_5
# Curious what X contains? :
#  Subject_5
# Curious what X contains? :
#  Subject_5
# Curious what X contains? :
#  Subject_5
# Curious what X contains? :
#  Subject_5
# Curious what X contains? :
#  Subject_5
# Curious what X contains? :
#  Subject_5
# Curious what X contains? :
#  Subject_5
# Curious what X contains? :
#  Subject_5
# Curious what X contains? :
#  Subject_5
# Curious what X contains? :
#  Subject_5
# Curious what X contains? :
#  Subject_5
# Curious what X contains? :
#  Subject_5
# Curious what X contains? :
#  7.764332406101751
# Curious what X contains? :
#  1.01651714832016
# Curious what X contains? :
#  5.368877263146126
# Curious what X contains? :
#  8.659473136165527
# Curious what X contains? :
#  2.513092973733085
# Curious what X contains? :
#  1.025798131060464
# Curious what X contains? :
#  4.6974609103759395
# Curious what X contains? :
#  2.382766659808275
# Curious what X contains? :
#  4.978439387475342
# Curious what X contains? :
#  3.079344122353957
# Curious what X contains? :
#  6.116709350288181
# Curious what X contains? :
#  2.776466101494334
# Curious what X contains? :
#  2.1668980550384926
# Curious what X contains? :
#  7.519082191565814
# Curious what X contains? :
#  8.68299943527786
# Curious what X contains? :
#  4.8191262349347905
# Curious what X contains? :
#  3.2514549030700737
# Curious what X contains? :
#  3.73370118191026
# Curious what X contains? :
#  2.344697016572529
# Curious what X contains? :
#  9.861274945680229
# Curious what X contains? :
#  6.800769828812934
# Curious what X contains? :
#  8.395963815562542
# Curious what X contains? :
#  8.662749976834158
# Curious what X contains? :
#  6.953821981134405
# Curious what X contains? :
#  8.386742658937951
# Curious what X contains? :
#  5.5141482290027
# Curious what X contains? :
#  5.821019675143823
# Curious what X contains? :
#  7.653976192892014
# Curious what X contains? :
#  3.9551903996587257
# Curious what X contains? :
#  9.189052499299862
# Curious what X contains? :
#  3.936514294000765
# Curious what X contains? :
#  4.783644603767593
# Curious what X contains? :
#  4.177116535560925
# Curious what X contains? :
#  9.449659595354737
# Curious what X contains? :
#  8.898931934549896
# Curious what X contains? :
#  8.167427469250214
# Curious what X contains? :
#  7.563720046006591
# Curious what X contains? :
#  3.0607474869381126
# Curious what X contains? :
#  2.6749768305814703
# Curious what X contains? :
#  4.86811341196856
# Curious what X contains? :
#  8.0
# Curious what X contains? :
#  2.0
# Curious what X contains? :
#  6.0
# Curious what X contains? :
#  9.0
# Curious what X contains? :
#  3.0
# Curious what X contains? :
#  2.0
# Curious what X contains? :
#  5.0
# Curious what X contains? :
#  3.0
# Curious what X contains? :
#  5.0
# Curious what X contains? :
#  4.0
# Curious what X contains? :
#  7.0
# Curious what X contains? :
#  3.0
# Curious what X contains? :
#  3.0
# Curious what X contains? :
#  8.0
# Curious what X contains? :
#  9.0
# Curious what X contains? :
#  5.0
# Curious what X contains? :
#  4.0
# Curious what X contains? :
#  4.0
# Curious what X contains? :
#  3.0
# Curious what X contains? :
#  10.0
# Curious what X contains? :
#  7.0
# Curious what X contains? :
#  9.0
# Curious what X contains? :
#  9.0
# Curious what X contains? :
#  7.0
# Curious what X contains? :
#  9.0
# Curious what X contains? :
#  6.0
# Curious what X contains? :
#  6.0
# Curious what X contains? :
#  8.0
# Curious what X contains? :
#  4.0
# Curious what X contains? :
#  10.0
# Curious what X contains? :
#  4.0
# Curious what X contains? :
#  5.0
# Curious what X contains? :
#  5.0
# Curious what X contains? :
#  10.0
# Curious what X contains? :
#  9.0
# Curious what X contains? :
#  9.0
# Curious what X contains? :
#  8.0
# Curious what X contains? :
#  4.0
# Curious what X contains? :
#  3.0
# Curious what X contains? :
#  5.0
# Curious what X contains? :
#  A
# Curious what X contains? :
#  Nailed it.!
# Curious what X contains? :
#  C
# Curious what X contains? :
#  E
# Curious what X contains? :
#  F
# Curious what X contains? :
#  Nailed it.!
# Curious what X contains? :
#  D
# Curious what X contains? :
#  F
# Curious what X contains? :
#  D
# Curious what X contains? :
#  E
# Curious what X contains? :
#  B
# Curious what X contains? :
#  F
# Curious what X contains? :
#  F
# Curious what X contains? :
#  A
# Curious what X contains? :
#  E
# Curious what X contains? :
#  D
# Curious what X contains? :
#  E
# Curious what X contains? :
#  E
# Curious what X contains? :
#  F
# Curious what X contains? :
#  O
# Curious what X contains? :
#  B
# Curious what X contains? :
#  E
# Curious what X contains? :
#  E
# Curious what X contains? :
#  B
# Curious what X contains? :
#  E
# Curious what X contains? :
#  C
# Curious what X contains? :
#  C
# Curious what X contains? :
#  A
# Curious what X contains? :
#  E
# Curious what X contains? :
#  O
# Curious what X contains? :
#  E
# Curious what X contains? :
#  D
# Curious what X contains? :
#  D
# Curious what X contains? :
#  O
# Curious what X contains? :
#  E
# Curious what X contains? :
#  E
# Curious what X contains? :
#  A
# Curious what X contains? :
#  E
# Curious what X contains? :
#  F
# Curious what X contains? :
#  D
